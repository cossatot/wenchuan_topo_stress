# %%
# %pylab inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
cols = ['lon', 'lat', 'depth', 'slip_cm', 'rake', 'time_s', 'strike', 'dip']

# %%
zz = pd.read_csv('zhang_sgm.csv', names=cols)

# %%
zz
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102 entries, 0 to 101
# Data columns (total 8 columns):
# lon        102  non-null values
# lat        102  non-null values
# depth      102  non-null values
# slip_cm    102  non-null values
# rake       102  non-null values
# time_s     102  non-null values
# strike     102  non-null values
# dip        102  non-null values
# dtypes: float64(6), int64(2)

# %%
scatter(zz.lat, -zz.depth, c=zz.c3, s=30, lw=0)
colorbar()
show()

# %%
scatter(zz.lat, -zz.depth, c=zz.c4, s=30, lw=0)
colorbar()
show()

# %%
scatter(zz.lat, -zz.depth, c=zz.c5, s=30, lw=0)
colorbar()
show()
