# %%
import numpy as np
import pandas as pd
import halfspace.projections as hsp

# %%
df = pd.read_csv('../slip_models/zhang/lms_stress_slip.csv',
                     index_col=0)

# %%
df
# Out:
#     lat_deg   lon_deg  depth_km  slp_strk_m  slp_ddip_m  slp_am_m  strike_deg  \
# 0   32.6006  105.3810    1.9696      1.2616      0.1872    1.2755         230
# 1   32.6054  105.3762    5.9088      1.4475      0.1238    1.4528         230
# 2   32.6102  105.3715    9.8481      1.4525      0.0435    1.4532         230
# 3   32.6150  105.3667   13.7873      1.2829     -0.0000    1.2829         230
# 4   32.6198  105.3619   17.7265      1.0385     -0.0000    1.0385         230
# 5   32.6246  105.3572   21.6658      0.7792     -0.0000    0.7792         230
# 6   32.6294  105.3524   25.6050      0.5151     -0.0000    0.5151         230
# 7   32.6341  105.3476   29.5442      0.2432     -0.0000    0.2432         230
# 8   32.5772  105.3478    1.9696      2.0044      0.1660    2.0113         230
# 9   32.5819  105.3430    5.9088      2.2840      0.1032    2.2863         230
# 10  32.5867  105.3383    9.8481      2.3488      0.0210    2.3489         230
# ...

# %%
df.iloc[226]
# Out:
# lat_deg        31.918900
# lon_deg       104.489200
# depth_km        9.396900
# slp_strk_m      2.538000
# slp_ddip_m      1.719800
# slp_am_m        3.065800
# strike_deg    222.000000
# dip_deg        70.000000
# rake_deg       55.877641
# xx_stress      23.209010
# yy_stress      33.825072
# xy_stress       0.569907
# zz_stress      35.341309
# xz_stress       3.225047
# yz_stress      -3.758598
# Name: 226, dtype: float64

# %%
np.radians(70)
# Out:
# 1.2217304763960306

# %%
np.radians(222)
# Out:
# 3.8746309394274117

# %%
np.radians(55.877641)
# Out:
# 0.9752488136973767
