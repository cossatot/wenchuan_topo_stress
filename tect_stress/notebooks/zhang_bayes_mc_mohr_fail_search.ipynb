# %%
# %pylab inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.append('../scripts/')

import numpy as np
import pandas as pd
import halfspace.projections as hsp
import stress_comps_vectorized as scv
import time
from matplotlib import gridspec

# %%
lms = pd.read_csv('../../slip_models/zhang/lms_stress_slip.csv', index_col=0)

lms.head()
# Out:
#    lat_deg   lon_deg  depth_km  slp_strk_m  slp_ddip_m  slp_am_m  strike_deg  \
# 0  32.6006  105.3810    1.9696      1.2616      0.1872    1.2755         230
# 1  32.6054  105.3762    5.9088      1.4475      0.1238    1.4528         230
# 2  32.6102  105.3715    9.8481      1.4525      0.0435    1.4532         230
# 3  32.6150  105.3667   13.7873      1.2829     -0.0000    1.2829         230
# 4  32.6198  105.3619   17.7265      1.0385     -0.0000    1.0385         230
#
#    dip_deg   rake_deg  xx_stress  yy_stress  xy_stress  zz_stress  xz_stress  \
# 0       80  81.559864  10.976253  30.172523   1.070611  19.372076   1.869993
# 1       80  85.111573  14.771017  32.375621   0.144774  23.582459   2.119628
# 2       80  88.284598  16.941882  32.419915   0.053586  25.794262   2.885399
# 3       80  90.000000  18.737585  32.405041   0.002823  27.119895   3.481674
# 4       80  90.000000  20.285801  32.359863  -0.074297  28.114629   4.028200
#
#    yz_stress
# 0   2.392969
# 1  -0.145302
# 2  -1.199046
# 3  -1.899954
# 4  -2.539007

# %%
t_prior_df = pd.read_csv('../results/l2_tect_posteriors.csv')

# %%
# for testing's sake
#t_prior_df = t_prior_df.iloc[:500]

# %%
t_priors = t_prior_df.values

del t_prior_df

# %%
n_trials = t_priors.shape[0]

n_points = len(lms.index)

# %%
rho = 2700
g = 9.81

# %%
lamb_priors = np.random.random(n_trials)

# %%
search_df_cols = ['iter','txx', 'tyy', 'txy', 'pt_index',
                  'depth', 'strike', 'dip', 'slip_m',
                  'slip_rake', 'lamb']

# %%
iter_range = np.arange(n_trials, dtype='float')
pt_range = np.arange(n_points, dtype='float')

# %%
index_list = [[iter_range[i], lamb_priors[i], t_priors[i,0],
               t_priors[i,1], t_priors[i,2], pi]
             for i in iter_range for pi in pt_range]

index_array= np.array(index_list)
del index_list

iter_index = np.int_(index_array[:,0].copy() )
pt_index = np.int_(index_array[:,5].copy() )
lamb_prior_array = index_array[:,1]
t_prior_array = index_array[:,2:5]

del index_array

# %%
t_prior_array.shape
# Out:
# (3244644, 3)

# %%
n_trials
# Out:
# 4622

# %%
search_df=pd.DataFrame(index=np.arange(len(iter_index)), 
                       columns=search_df_cols, dtype=float)

# %%
search_df['iter'] = iter_index
search_df['lamb'] = lamb_prior_array
search_df['pt_index'] = pt_index
search_df[['txx', 'tyy', 'txy']] = t_prior_array

# %%
search_df['mxx'] = 0.
search_df['myy'] = 0.
search_df['mxy'] = 0.
search_df['mxz'] = 0.
search_df['myz'] = 0.
search_df['mzz'] = 0.

# %%
lms_fill_cols = ['depth', 'strike', 'dip', 'slip_m', 'slip_rake',
                       'mxx', 'myy', 'mxy', 'mzz', 'mxz', 'myz']

# %%
lms_copy_cols = ['depth_km', 'strike_deg','dip_deg','slp_am_m', 'rake_deg',
                'xx_stress', 'yy_stress', 'xy_stress', 'zz_stress',
                'xz_stress', 'yz_stress']

lms_col_array = lms[lms_copy_cols].values

lms_reps = np.tile(lms_col_array, [n_trials, 1])

search_df[lms_fill_cols] = lms_reps

search_df.depth *= 1000

search_df[['mxx', 'myy', 'mxy', 'mzz', 'mxz', 'myz']] *= 1e6

# %%
search_df.head()
# Out:
#    iter      txx       tyy       txy  pt_index    depth  strike  dip  slip_m  \
# 0     0  1.53341  0.067958  0.294583         0   1969.6     230   80  1.2755
# 1     0  1.53341  0.067958  0.294583         1   5908.8     230   80  1.4528
# 2     0  1.53341  0.067958  0.294583         2   9848.1     230   80  1.4532
# 3     0  1.53341  0.067958  0.294583         3  13787.3     230   80  1.2829
# 4     0  1.53341  0.067958  0.294583         4  17726.5     230   80  1.0385
#
#    slip_rake      lamb              mxx              myy             mxy  \
# 0  81.559864  0.242336  10976253.429215  30172522.971082  1070610.613817
# 1  85.111573  0.242336  14771017.091866  32375620.692125   144773.771068
# 2  88.284598  0.242336  16941881.697796  32419914.711392    53585.715643
# 3  90.000000  0.242336  18737584.977646  32405040.891478     2823.373489
# 4  90.000000  0.242336  20285801.406380  32359863.473484   -74297.376346
#
#               mxz             myz              mzz
# 0  1869992.542014  2392968.966096  19372076.331012
# 1  2119627.817813  -145301.740365  23582459.219956
# 2  2885398.716198 -1199046.070224  25794262.126200
# 3  3481674.488299 -1899954.301269  27119894.734741
# 4  4028200.086796 -2539007.345327  28114629.179667

# %%
search_df['tau_s'] = scv.strike_shear(strike = search_df.strike, 
                          dip=search_df.dip, rho=rho, g=g,
                          mxx=search_df.mxx, myy=search_df.myy,
                          mxy=search_df.mxy, mzz=search_df.mzz,
                          mxz=search_df.mxz, myz=search_df.myz,
                          txx=search_df.txx, tyy=search_df.tyy,
                          txy=search_df.txy, depth=search_df.depth)

# %%
search_df['tau_d'] = scv.dip_shear(strike = search_df.strike, 
                          dip=search_df.dip, rho=rho, g=g,
                          mxx=search_df.mxx, myy=search_df.myy,
                          mxy=search_df.mxy, mzz=search_df.mzz,
                          mxz=search_df.mxz, myz=search_df.myz,
                          txx=search_df.txx, tyy=search_df.tyy,
                          txy=search_df.txy, depth=search_df.depth)

# %%
search_df['sig_n_eff'] = scv.eff_normal_stress(strike = search_df.strike, 
                          dip=search_df.dip, rho=rho, g=g,
                          mxx=search_df.mxx, myy=search_df.myy,
                          mxy=search_df.mxy, mzz=search_df.mzz,
                          mxz=search_df.mxz, myz=search_df.myz,
                          txx=search_df.txx, tyy=search_df.tyy,
                          txy=search_df.txy, depth=search_df.depth,
                          lamb=search_df.lamb)

# %%
search_df['tau_mag'] = np.sqrt(search_df.tau_s**2 + search_df.tau_d**2)

# %%
#search_df.describe()

# %%
mean_slip = lms.slp_am_m.mean()

search_df['weighted_tau_mag'] = (search_df.tau_mag * search_df.slip_m 
                             / mean_slip)

# %%
iters = search_df.groupby('iter')

# %%
mu_iter = iters.weighted_tau_mag.mean() / iters.sig_n_eff.mean()

# %%
iters.weighted_tau_mag.mean().min()
# Out:
# 16430463.789752772

# %%
iters.sig_n_eff.mean().hist(bins=50)

# %%
mu_iter.describe()
# Out:
# count    4622.000000
# mean        0.623341
# std         4.830606
# min      -165.943138
# 25%         0.269646
# 50%         0.398651
# 75%         0.711577
# max       128.642120
# dtype: float64

# %%
mu_real = mu_iter[(0 <= mu_iter) & (mu_iter <= 1)]

# %%
mu_real.describe()
# Out:
# count    3727.000000
# mean        0.416468
# std         0.201574
# min         0.081673
# 25%         0.264916
# 50%         0.356544
# 75%         0.525555
# max         0.997909
# dtype: float64

# %%
lamb_iters = iters.lamb.mean()

# %%
lamb_keep = lamb_iters[mu_real.index]

# %%
txx_keep = iters.txx.mean()[mu_real.index]
tyy_keep = iters.tyy.mean()[mu_real.index]
txy_keep = iters.txy.mean()[mu_real.index]

# %%
figure(1)
lamb_keep.hist(bins=50)
xlabel('pore fluid pressure')

figure(2)
mu_real.hist(bins=50)
xlabel('friction coefficient')

figure(3)
scatter(lamb_keep, mu_real, c=txx_keep,
        s=8, lw=0, alpha=0.2)
colorbar()
xlabel('pore fluid pressure')
ylabel('friction')

# %%
def scatter_w_marginals(x_data, y_data, c=None,
                        lw=1, s=10, alpha=1,
                        bins=10, xlabel='',
                        ylabel=''):
    
    figure()
    x_lim = (x_data.min(), x_data.max())
    y_lim = (y_data.min(), y_data.max())
    
    gs = gridspec.GridSpec(2, 2, width_ratios=[3,1],
                                 height_ratios=[1,3])
    ax = subplot(gs[1,0])
    axt = subplot(gs[0,0], sharex=ax)
    axl = subplot(gs[1,1], sharey=ax)
    
    axt.hist(x_data, bins=bins)
    axl.hist(y_data, bins=bins, orientation='horizontal')
    
    sc = ax.scatter(x_data, y_data, c=c, lw=lw, s=s, alpha=alpha)
    #colorbar(sc)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    #ax.colorbar()
    ax.set_xlim([0,1])
    ax.set_ylim([0,1])
    #ylim(y_lim)
    

    
    return figure()

# %%
figure(1)

scatter_w_marginals(lamb_keep, mu_real, c=txx_keep, 
                    lw=0, s=5, bins=50, xlabel='fluid pressure',
                    ylabel='friction')

show()

# %%
np.random.seed(69)

# %%
np.random.randint(0, 100, 30)
# Out:
# array([54, 75, 73, 90, 55, 20, 49, 22,  9, 56, 97, 38, 96, 88, 12, 37, 75,
#        53,  3, 80, 39, 24,  2, 99, 39, 24, 47, 90, 75, 44])

# %%
np.random.randint(0, 100, 30)
# Out:
# array([23, 35, 43, 86, 14, 21, 49, 70, 69, 76, 14, 14, 91, 61, 48, 45, 16,
#        93, 83, 63, 11, 78, 18, 44, 24, 78, 29,  0, 45, 62])
