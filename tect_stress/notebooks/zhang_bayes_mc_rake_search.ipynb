# %%
# %pylab inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.append('../scripts/')

# %%
import numpy as np
import pandas as pd
import halfspace.projections as hsp
import time
import stress_comps_vectorized as scv

# %%
reload(scv)
# Out:
# <module 'stress_comps_vectorized' from '../scripts/stress_comps_vectorized.py'>

# %%
lms = pd.read_csv('../../slip_models/zhang/lms_stress_slip.csv', index_col=0)

lms.head()
# Out:
#    lat_deg   lon_deg  depth_km  slp_strk_m  slp_ddip_m  slp_am_m  strike_deg  \
# 0  32.6006  105.3810    1.9696      1.2616      0.1872    1.2755         230
# 1  32.6054  105.3762    5.9088      1.4475      0.1238    1.4528         230
# 2  32.6102  105.3715    9.8481      1.4525      0.0435    1.4532         230
# 3  32.6150  105.3667   13.7873      1.2829     -0.0000    1.2829         230
# 4  32.6198  105.3619   17.7265      1.0385     -0.0000    1.0385         230
#
#    dip_deg   rake_deg  xx_stress  yy_stress  xy_stress  zz_stress  xz_stress  \
# 0       80  81.559864  10.976253  30.172523   1.070611  19.372076   1.869993
# 1       80  85.111573  14.771017  32.375621   0.144774  23.582459   2.119628
# 2       80  88.284598  16.941882  32.419915   0.053586  25.794262   2.885399
# 3       80  90.000000  18.737585  32.405041   0.002823  27.119895   3.481674
# 4       80  90.000000  20.285801  32.359863  -0.074297  28.114629   4.028200
#
#    yz_stress
# 0   2.392969
# 1  -0.145302
# 2  -1.199046
# 3  -1.899954
# 4  -2.539007
#
# [5 rows x 15 columns]

# %%
n_trials = 2e4

n_points = len(lms.index)

# %%
rho = 2700
g = 9.81

# %%
s1s = np.random.uniform(1,2.5, n_trials)
s3s = np.random.uniform(0, 1, n_trials) * s1s
thetas = np.random.uniform(0, 2 * np.pi, n_trials)

xxs = scv.xx_stress_from_s1_s3_theta(s1s, s3s, thetas)
yys = scv.yy_stress_from_s1_s3_theta(s1s, s3s, thetas)
xys = scv.xy_stress_from_s1_s3_theta(s1s, s3s, thetas)

del s1s, s3s, thetas

# %%
xxs = xxs.reshape([n_trials, 1])
yys = yys.reshape([n_trials, 1])
xys = xys.reshape([n_trials, 1])

# %%
t_priors = np.concatenate((xxs, yys, xys), axis=1)

t_priors.shape
# Out:
# (20000, 3)

# %%
search_df_cols = ['iter','txx', 'tyy', 'txy', 'pt_index',
                  'depth', 'strike', 'dip', 'slip_m',
                  'slip_rake']

# %%
iter_range = np.arange(n_trials, dtype='float')
pt_range = np.arange(n_points, dtype='float')

# %%
index_list = [[iter_range[i],t_priors[i,0],t_priors[i,1],t_priors[i,2], pi]
             for i in iter_range for pi in pt_range]

index_array= np.array(index_list)
del index_list

iter_index = np.int_(index_array[:,0].copy() )
pt_index = np.int_(index_array[:,4].copy() )
prior_array = index_array[:,1:4]

del index_array
#index_array.shape

# %%
search_df=pd.DataFrame(index=np.arange(len(iter_index)), 
                       columns=search_df_cols, dtype=float)

# %%
search_df['iter'] = iter_index
search_df[search_df_cols[1:4]]=prior_array
search_df['pt_index'] = pt_index

# %%
search_df.head()
# Out:
#    iter       txx       tyy       txy  pt_index  depth  strike  dip  slip_m  \
# 0     0  0.623616  1.270117  0.210766         0    NaN     NaN  NaN     NaN
# 1     0  0.623616  1.270117  0.210766         1    NaN     NaN  NaN     NaN
# 2     0  0.623616  1.270117  0.210766         2    NaN     NaN  NaN     NaN
# 3     0  0.623616  1.270117  0.210766         3    NaN     NaN  NaN     NaN
# 4     0  0.623616  1.270117  0.210766         4    NaN     NaN  NaN     NaN
#
#    slip_rake
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 10 columns]

# %%
search_df['mxx'] = 0.
search_df['myy'] = 0.
search_df['mxy'] = 0.
search_df['mxz'] = 0.
search_df['myz'] = 0.
search_df['mzz'] = 0.

# %%
lms_fill_cols = ['depth', 'strike', 'dip', 'slip_m', 'slip_rake',
                       'mxx', 'myy', 'mxy', 'mzz', 'mxz', 'myz']

lms_copy_cols = ['depth_km', 'strike_deg','dip_deg','slp_am_m', 'rake_deg',
                'xx_stress', 'yy_stress', 'xy_stress', 'zz_stress',
                'xz_stress', 'yz_stress']

lms_col_array = lms[lms_copy_cols].values

lms_reps = np.tile(lms_col_array, [n_trials, 1])

search_df[lms_fill_cols] = lms_reps

search_df.depth *= 1000

search_df[['mxx', 'myy', 'mxy', 'mzz', 'mxz', 'myz']] *= 1e6

# %% [markdown]
# ## OK, now let's do some calculations

# %%
search_df['tau_s'] = scv.strike_shear(strike = search_df.strike, 
                          dip=search_df.dip, rho=rho, g=g,
                          mxx=search_df.mxx, myy=search_df.myy,
                          mxy=search_df.mxy, mzz=search_df.mzz,
                          mxz=search_df.mxz, myz=search_df.myz,
                          txx=search_df.txx, tyy=search_df.tyy,
                          txy=search_df.txy, depth=search_df.depth)

# %%
search_df['tau_d'] = scv.dip_shear(strike = search_df.strike, 
                          dip=search_df.dip, rho=rho, g=g,
                          mxx=search_df.mxx, myy=search_df.myy,
                          mxy=search_df.mxy, mzz=search_df.mzz,
                          mxz=search_df.mxz, myz=search_df.myz,
                          txx=search_df.txx, tyy=search_df.tyy,
                          txy=search_df.txy, depth=search_df.depth)

# %%
search_df['tau_rake'] = np.degrees( np.arctan2( search_df.tau_d, 
                                                search_df.tau_s) )

# %%
search_df['rake_misfit_rad'] = np.radians(scv.angle_difference(search_df.slip_rake,
                                                               search_df.tau_rake) )

# %%
mean_slip = lms.slp_am_m.mean()
max_slip = lms.slp_am_m.max()
rake_err = np.cos( np.pi/9. )

search_df['chi_sq'] = ((0.5 * (-np.cos(search_df.rake_misfit_rad) + 1) )**2 
                        * search_df.slip_m / (rake_err**2 *  max_slip) )

search_df['weighted_diff'] = (0.5 * (-np.cos(search_df.rake_misfit_rad) + 1)
                              * search_df.slip_m / (rake_err * max_slip) )

#search_df['fish'] = (search_df.rake_misfit_rad

# %%
search_df.rake_misfit_rad.hist(bins=50)

# %%
search_df.weighted_diff.hist(bins=50)

# %%
search_df.chi_sq.hist(bins=50)

# %%
iters = search_df.groupby('iter')

# %% [markdown]
# $ \exp \{- \frac{1}{2}  \sqrt{ \Sigma \frac{|p_i - o_i|^2 s_i}{\bar{s}} } \}$

# %% [markdown]
# $ \exp \{- \frac{1}{2}  \sqrt{ \Sigma \frac{|p_i - o_i|^2 \sigma_r s_{max}}{s_i} } \}$

# %% [markdown]
# $ \exp \left\{- \frac{1}{2}  \Sigma \frac{|p_i - o_i|^2  s_{i}}{\sigma^2 s_{max}} \right\}$

# %% [markdown]
# $ \exp \{- \frac{1}{2}  \sqrt{ \Sigma \frac{|p_i - o_i|^2 \sigma_r s_i}{s_{max}} } \}$

# %% [markdown]
# Use the same error on all fault points, so that the total uncertainty that would take into account the slip magnitude weighting should be:
# sigma_rake*max[s]/s_i
# note mean[s]->max[s] just so that the minimum uncertainty in the likelihood calc is sigma_rake and not >sigma_rake.

# %%
def l2(array):
    return np.linalg.norm(array, 2)

# %%
#iter_l2 = iters.chi_sq.apply(l2)
iter_l2 = iters.chi_sq.sum()
iter_l1 = iters.weighted_diff.sum()

iter_l1n = iter_l1 - iter_l1.min()
iter_l2n = iter_l2 - iter_l2.min()

# %%
iter_l1.describe()
# Out:
# count    20000.000000
# mean        46.192486
# std         31.192935
# min         14.609134
# 25%         22.024855
# 50%         34.722621
# 75%         60.724605
# max        162.569189
# Name: weighted_diff, dtype: float64

# %%
iter_l1n.describe()
# Out:
# count    20000.000000
# mean        31.583352
# std         31.192935
# min          0.000000
# 25%          7.415721
# 50%         20.113488
# 75%         46.115471
# max        147.960055
# Name: weighted_diff, dtype: float64

# %%
iter_l2.describe()
# Out:
# count    20000.000000
# mean        21.426894
# std         24.747815
# min          2.502675
# 25%          5.521232
# 50%         10.878885
# 75%         26.262377
# max        150.902541
# Name: chi_sq, dtype: float64

# %%
iter_l2n.describe()
# Out:
# count    20000.000000
# mean        18.924219
# std         24.747815
# min          0.000000
# 25%          3.018556
# 50%          8.376209
# 75%         23.759702
# max        148.399865
# Name: chi_sq, dtype: float64

# %%
iter_lp1 = np.exp( -np.sqrt(2)* iter_l1n)
iter_lp2 = np.exp( - 0.5 * iter_l2n**2 )

# %%
iter_lp1.describe()
# Out:
# count    2.000000e+04
# mean     1.445108e-02
# std      5.689606e-02
# min      1.333926e-91
# 25%      4.748582e-29
# 50%      4.431949e-13
# 75%      2.788523e-05
# max      1.000000e+00
# Name: weighted_diff, dtype: float64

# %%
iter_lp2.describe()
# Out:
# count     2.000000e+04
# mean      1.283890e-01
# std       2.789956e-01
# min       0.000000e+00
# 25%      2.629847e-123
# 50%       5.817790e-16
# 75%       1.050566e-02
# max       1.000000e+00
# Name: chi_sq, dtype: float64

# %%
figure(1)
iter_l1.hist(bins=50)
xlabel('l1')

figure(2)
iter_l1n.hist(bins=50)
xlabel('l1 - l1_min')

# %%
figure(1)
iter_l2.hist(bins=50)
xlabel('l2')

figure(2)
iter_l2n.hist(bins=50)
xlabel('l2 - l2_min')

# %%
iter_l1_likelihood = iter_lp1 #/ iter_lp1.max()

iter_l2_likelihood = iter_lp2 #/ iter_lp2.max()

# %%
iter_l1_likelihood.hist(bins=100)

# %%
iter_l2_likelihood.hist(bins=100)

# %%
rand_filter = np.random.random(n_trials)

# %%
l1_keeps = iter_l1_likelihood[iter_l1_likelihood >= rand_filter]
l2_keeps = iter_l2_likelihood[iter_l2_likelihood >= rand_filter]

# %%
len(l1_keeps), len(l2_keeps)
# Out:
# (300, 2572)

# %%
l1_keeps.hist(bins=50)

# %%
l2_keeps.hist(bins=50)

# %%
iters_txx = iters.txx.mean()
iters_tyy = iters.tyy.mean()
iters_txy = iters.txy.mean()

# %%
txx_keep = iters_txx[l2_keeps.index]
txy_keep = iters_txy[l2_keeps.index]
tyy_keep = iters_tyy[l2_keeps.index]

# %%
iters[['txx', 'tyy', 'txy']].mean().iloc[l2_keeps.index]#[l2_keeps.index]
# Out:
#            txx       tyy       txy
# iter
# 112   1.775583  0.963431  0.355361
# 114   1.739647  0.858856  0.358318
# 142   1.952901  1.310334  0.630737
# 143   1.281728  0.703011  0.308046
# 225   2.356621  1.250792  0.394178
# 583   1.845088  0.931538  0.217584
# 711   1.310301  0.801752  0.277241
# 717   1.729032  1.122804  0.386431
# 785   1.274626  0.701833  0.297970
# 859   1.262440  0.702004  0.188246
# 879   1.145669  0.659374  0.240901
# 965   1.415983  0.889181  0.225712
# 1074  2.428899  1.228858  0.228257
# 1137  1.940416  1.142138  0.433219
# 1207  1.154147  0.617006  0.157376
# 1381  1.381737  0.870630  0.287810
# 1410  1.931628  1.197846  0.419708
# 1455  1.490563  0.781634  0.335667
# 1470  1.758738  0.955729  0.488311
# 1541  1.804448  1.045402  0.283291
# 1664  2.258590  1.255886  0.263514
# 1776  1.217747  0.580279  0.148637
# 1837  1.299746  0.719430  0.232627
# 1982  1.553757  0.876548  0.364089
# 1984  1.273810  0.658893  0.023357
# 2220  2.106350  1.097725  0.331185
# 2267  1.837529  0.825589  0.327428
# 2361  1.398517  0.702359  0.177712
# 2513  1.446640  0.794889  0.252505
# 2556  1.868148  1.093903  0.353431
# 2623  1.775222  1.032109  0.350890
# 2695  1.568186  0.873921  0.325625
# 2719  2.079425  1.092569  0.401162
# 2742  1.215416  0.674707  0.281782
# 2880  2.052037  1.325801  0.492112
# 3116  1.468331  0.783511  0.207485
# 3126  1.895235  1.078139  0.350187
# 3147  1.865990  1.035882  0.345885
# 3176  2.270570  1.018797  0.148724
# 3207  2.243671  1.091891  0.189876
# 3290  1.735747  0.815897  0.271461
# 3343  2.239430  1.280790  0.347720
# 3470  2.061541  1.129794  0.361003
# 3564  2.336901  1.069212  0.167947
# 3574  2.099987  1.416110  0.628260
# 3724  1.916170  0.908823  0.409676
# 3952  2.282404  1.476528  0.441832
# 3992  2.172533  1.111216  0.463180
# 4020  2.041470  1.148188  0.284154
# 4031  2.012572  1.245769  0.337841
# 4050  1.402909  0.729591  0.061988
# 4094  1.990182  1.235769  0.582772
# 4256  1.651708  1.012688  0.391289
# 4372  2.043660  0.926778  0.111896
# 4451  2.046935  1.081634  0.409777
# 4602  1.955544  1.321046  0.508133
# 4728  1.867635  0.855723  0.308544
# 4751  2.199956  1.211215  0.584731
# 4833  1.617359  0.978223  0.373868
# 4916  2.114638  1.197533  0.561192
#            ...       ...       ...
#
# [224 rows x 3 columns]

# %%
tau_posteriors = pd.concat([txx_keep, tyy_keep, txy_keep], axis=1,
                           names=['txx', 'tyy', 'txy'])

tau_posteriors.to_csv('../results/tau_posteriors.csv', index=False)

# %%
#tau_posteriors

# %%
scatter(iters.txx.mean(), iters.tyy.mean(),c=iter_l2_likelihood,
        s=10, lw=0, alpha=0.2)
#colorbar()
axis('equal')
xlabel('txx')
ylabel('tyy')

# %%
scatter(txx_keep, tyy_keep, c=txy_keep,
        s=10, lw=0, alpha=0.5)
colorbar()
axis('equal')
xlabel('txx')
ylabel('tyy')

# %%
scatter(iters.txx.mean(), iters.txy.mean(), c=iter_l2_likelihood,
        s=10, lw=0, alpha=0.2)
colorbar()
axis('equal')
xlabel('txx')
ylabel('txy')

# %%
scatter(iters.txy.mean(), iters.tyy.mean(), c=iter_l2_likelihood,
        s=10, lw=0, alpha=0.2)
colorbar()
axis('equal')
xlabel('txy')
ylabel('tyy')

# %%
len(txx_keep)
# Out:
# 2572

# %%
def make_xy_stress_tensor(s_xx=0, s_yy=0, s_xy=0):
    T = np.matrix([[s_xx, s_xy],
                   [s_xy, s_yy]])
    
    return T

def get_princ_stress_dirs(T):
    vals, vecs = hsp.sorted_eigens(T)
    vecs = np.array(vecs)
    
    max_x = vecs[0,1] * vals[1]
    max_y = vecs[1,1] * vals[1]
    min_x = vecs[0,0] * vals[0]
    min_y = vecs[1,0] * vals[0]
    
    return max_x, max_y, min_x, min_y


def calc_princ_stress_dirs_from_tensor(s_xx=0, s_yy=0, s_xy=0):
    T = make_xy_stress_tensor(s_xx=s_xx, s_yy=s_yy, s_xy=s_xy)
    
    max_x, max_y, min_x, min_y = get_princ_stress_dirs(T)
    return max_x, max_y, min_x, min_y

# %%
Xa = []
Ya = []
xa = []
ya = []


for i in np.arange(len(txx_keep.values)):
    
    XX, YY, xx, yy = calc_princ_stress_dirs_from_tensor(txx_keep.values[i],
                                                        tyy_keep.values[i],
                                                        txy_keep.values[i])
    #print(XX,YY)
    
    Xa.append(XX)
    Ya.append(YY)
    xa.append(xx)
    ya.append(yy)

# %%
Xa = np.array(Xa)
Ya = np.array(Ya)
xa = np.array(xa)
ya = np.array(ya)

# %%
figure(1)
scatter(Xa, Ya, c=l2_keeps.values,
        s=7, lw=0, alpha=0.2)
colorbar()
scatter(-Xa, -Ya, #c=l2_keeps.values,
        s=7, lw=0, alpha=0.2)
axis('equal')

figure(2)
scatter(xa, ya, c=l2_keeps.values,
        s=7, lw=0, alpha=0.2)
colorbar()
scatter(-xa, -ya, #c=l2_keeps.values,
        s=7, lw=0, alpha=0.2)
axis('equal')
# Out:
# (-1.0, 1.0, -2.0, 2.0)

# %%
figure(1)
for i in range( len(Xa)):
    plot([-Xa[i], Xa[i]], [-Ya[i], Ya[i]], 'b-', lw=0.1, alpha=0.2)
    #plot([0, Xa[i]], [0, Ya[i]], 'b-', lw=0.1, alpha=1)
axis('equal')

figure(2)
for i in range( len(Xa) ):
    plot([-xa[i], xa[i]], [-ya[i], ya[i]], 'r-', lw=0.1, alpha=0.2)
    #plot([0, xa[i]], [0, ya[i]], 'r-', lw=0.1, alpha=1)
axis('equal')

figure(3)
for i in range( len(Xa)):
    plot([-Xa[i], Xa[i]], [-Ya[i], Ya[i]], 'b-', lw=0.1, alpha=0.2)
    plot([-xa[i], xa[i]], [-ya[i], ya[i]], 'r-', lw=0.1, alpha=0.2)
    
axis('equal')    
show()

# %%
figure(1)
for i in range( len(Xa)):
    plot([-Xa[i], Xa[i]], [-Ya[i], Ya[i]], 'b-', lw=0.1, alpha=0.2)
    #plot([0, Xa[i]], [0, Ya[i]], 'b-', lw=0.1, alpha=1)
axis('equal')

figure(2)
for i in range( len(Xa) ):
    plot([-xa[i], xa[i]], [-ya[i], ya[i]], 'r-', lw=0.1, alpha=0.2)
    #plot([0, xa[i]], [0, ya[i]], 'r-', lw=0.1, alpha=1)
axis('equal')

figure(3)
for i in range( len(Xa)):
    plot([-Xa[i], Xa[i]], [-Ya[i], Ya[i]], 'b-', lw=0.1, alpha=0.2)
    plot([-xa[i], xa[i]], [-ya[i], ya[i]], 'r-', lw=0.1, alpha=0.2)
    
axis('equal')    
show()
