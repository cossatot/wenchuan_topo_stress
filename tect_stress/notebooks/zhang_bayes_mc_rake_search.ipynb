# %%
# %pylab inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.append('../scripts/')

# %%
import numpy as np
import pandas as pd
import halfspace.projections as hsp
import time
import stress_comps_vectorized as scv

# %%
lms = pd.read_csv('../../slip_models/zhang/lms_stress_slip.csv', index_col=0)

lms.head()
# Out:
#    lat_deg   lon_deg  depth_km  slp_strk_m  slp_ddip_m  slp_am_m  strike_deg  \
# 0  32.6006  105.3810    1.9696      1.2616      0.1872    1.2755         230
# 1  32.6054  105.3762    5.9088      1.4475      0.1238    1.4528         230
# 2  32.6102  105.3715    9.8481      1.4525      0.0435    1.4532         230
# 3  32.6150  105.3667   13.7873      1.2829     -0.0000    1.2829         230
# 4  32.6198  105.3619   17.7265      1.0385     -0.0000    1.0385         230
#
#    dip_deg   rake_deg  xx_stress  yy_stress  xy_stress  zz_stress  xz_stress  \
# 0       80  81.559864  10.976253  30.172523   1.070611  19.372076   1.869993
# 1       80  85.111573  14.771017  32.375621   0.144774  23.582459   2.119628
# 2       80  88.284598  16.941882  32.419915   0.053586  25.794262   2.885399
# 3       80  90.000000  18.737585  32.405041   0.002823  27.119895   3.481674
# 4       80  90.000000  20.285801  32.359863  -0.074297  28.114629   4.028200
#
#    yz_stress
# 0   2.392969
# 1  -0.145302
# 2  -1.199046
# 3  -1.899954
# 4  -2.539007
#
# [5 rows x 15 columns]

# %%
lms.rake_deg = hsp.get_rake_from_shear_components(strike_shear=lms.slp_strk_m,
                                                  dip_shear=lms.slp_ddip_m)

# %%
n_trials = 1.5e4

n_points = len(lms.index)

# %%
rho = 2700
g = 9.81

# %%
np.random.seed(69)

# %%
s1s = np.random.uniform(1,2.5, n_trials)
s3s = np.random.uniform(0, 1, n_trials) * s1s
thetas = np.random.uniform(0, 2 * np.pi, n_trials)

xxs = scv.xx_stress_from_s1_s3_theta(s1s, s3s, thetas)
yys = scv.yy_stress_from_s1_s3_theta(s1s, s3s, thetas)
xys = scv.xy_stress_from_s1_s3_theta(s1s, s3s, thetas)

del s1s, s3s, thetas

# %%
xxs = xxs.reshape([n_trials, 1])
yys = yys.reshape([n_trials, 1])
xys = xys.reshape([n_trials, 1])

# %%
t_priors = np.concatenate((xxs, yys, xys), axis=1)

# %%
search_df_cols = ['iter','txx', 'tyy', 'txy', 'pt_index',
                  'depth', 'strike', 'dip', 'slip_m',
                  'slip_rake']

# %%
iter_range = np.arange(n_trials, dtype='float')
pt_range = np.arange(n_points, dtype='float')

# %%
index_list = [[iter_range[i],t_priors[i,0],t_priors[i,1],t_priors[i,2], pi]
             for i in iter_range for pi in pt_range]

index_array= np.array(index_list)
del index_list

iter_index = np.int_(index_array[:,0].copy() )
pt_index = np.int_(index_array[:,4].copy() )
prior_array = index_array[:,1:4]

del index_array
#index_array.shape

# %%
search_df=pd.DataFrame(index=np.arange(len(iter_index)), 
                       columns=search_df_cols, dtype=float)

# %%
search_df['iter'] = iter_index
search_df[search_df_cols[1:4]]=prior_array
search_df['pt_index'] = pt_index

# %%
search_df.head()
# Out:
#    iter       txx       tyy       txy  pt_index  depth  strike  dip  slip_m  \
# 0     0  1.421935  0.400775 -0.153025         0    NaN     NaN  NaN     NaN
# 1     0  1.421935  0.400775 -0.153025         1    NaN     NaN  NaN     NaN
# 2     0  1.421935  0.400775 -0.153025         2    NaN     NaN  NaN     NaN
# 3     0  1.421935  0.400775 -0.153025         3    NaN     NaN  NaN     NaN
# 4     0  1.421935  0.400775 -0.153025         4    NaN     NaN  NaN     NaN
#
#    slip_rake
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 10 columns]

# %%
search_df['mxx'] = 0.
search_df['myy'] = 0.
search_df['mxy'] = 0.
search_df['mxz'] = 0.
search_df['myz'] = 0.
search_df['mzz'] = 0.

# %%
lms_fill_cols = ['depth', 'strike', 'dip', 'slip_m', 'slip_rake',
                       'mxx', 'myy', 'mxy', 'mzz', 'mxz', 'myz']

lms_copy_cols = ['depth_km', 'strike_deg','dip_deg','slp_am_m', 'rake_deg',
                'xx_stress', 'yy_stress', 'xy_stress', 'zz_stress',
                'xz_stress', 'yz_stress']

lms_col_array = lms[lms_copy_cols].values

lms_reps = np.tile(lms_col_array, [n_trials, 1])

search_df[lms_fill_cols] = lms_reps

del lms_reps

search_df.depth *= 1000

search_df[['mxx', 'myy', 'mxy', 'mzz', 'mxz', 'myz']] *= 1e6

# %%
#search_df.mxx = 0.
#search_df.myy = 0.
#search_df.mxy = 0.
#search_df.mzz = 0.
#search_df.mxz = 0.
#search_df.myz = 0.

#search_df.txx = 0.
#search_df.tyy=0.
#search_df.txy=0.

# %%
search_df.head()
# Out:
#    iter       txx       tyy       txy  pt_index    depth  strike  dip  slip_m  \
# 0     0  1.421935  0.400775 -0.153025         0   1969.6     230   80  1.2755
# 1     0  1.421935  0.400775 -0.153025         1   5908.8     230   80  1.4528
# 2     0  1.421935  0.400775 -0.153025         2   9848.1     230   80  1.4532
# 3     0  1.421935  0.400775 -0.153025         3  13787.3     230   80  1.2829
# 4     0  1.421935  0.400775 -0.153025         4  17726.5     230   80  1.0385
#
#     slip_rake              mxx              myy             mxy  \
# 0  171.559864  10976253.429215  30172522.971082  1070610.613817
# 1  175.111573  14771017.091866  32375620.692125   144773.771068
# 2  178.284598  16941881.697796  32419914.711392    53585.715643
# 3 -180.000000  18737584.977646  32405040.891478     2823.373489
# 4 -180.000000  20285801.406380  32359863.473484   -74297.376346
#
#               mxz             myz              mzz
# 0  1869992.542014  2392968.966096  19372076.331012
# 1  2119627.817813  -145301.740365  23582459.219956
# 2  2885398.716198 -1199046.070224  25794262.126200
# 3  3481674.488299 -1899954.301269  27119894.734741
# 4  4028200.086796 -2539007.345327  28114629.179667
#
# [5 rows x 16 columns]

# %% [markdown]
# ## OK, now let's do some calculations

# %%
search_df['tau_s'] = scv.strike_shear(strike = search_df.strike, 
                          dip=search_df.dip, rho=rho, g=g,
                          mxx=search_df.mxx, myy=search_df.myy,
                          mxy=search_df.mxy, mzz=search_df.mzz,
                          mxz=search_df.mxz, myz=search_df.myz,
                          txx=search_df.txx, tyy=search_df.tyy,
                          txy=search_df.txy, depth=search_df.depth)

# %%
search_df['tau_d'] = scv.dip_shear(strike = search_df.strike, 
                          dip=search_df.dip, rho=rho, g=g,
                          mxx=search_df.mxx, myy=search_df.myy,
                          mxy=search_df.mxy, mzz=search_df.mzz,
                          mxz=search_df.mxz, myz=search_df.myz,
                          txx=search_df.txx, tyy=search_df.tyy,
                          txy=search_df.txy, depth=search_df.depth)

# %%
search_df['tau_rake'] = hsp.get_rake_from_shear_components(search_df.tau_s, 
                                                           search_df.tau_d)

# %%
search_df['rake_misfit_rad'] = np.radians(scv.angle_difference(search_df.slip_rake,
                                                               search_df.tau_rake, 
                                                               return_abs=False) )

# %%
search_df.rake_misfit_rad.hist(bins=50)
title('rake misfit with all stresses')
xlabel('misfit, radians')
ylabel('count')

show()

# %%
search_df.tau_rake.hist(bins=50)
title('rake with all stresses')
xlabel('rake, degrees')
ylabel('count')

show()

# %%
sum_slip = lms.slp_am_m.sum()

search_df['weighted_diff'] = search_df.rake_misfit_rad.abs() * search_df.slip_m
search_df['w_diff_sq'] = search_df.rake_misfit_rad**2 * search_df.slip_m

# %%
search_df.weighted_diff.hist(bins=50)

# %%
iters = search_df.groupby('iter')

# %%
kappa = 8.529 #calculated so that 68.2% of von mises is within pi/9 of mean

# %%
fish_l1 = iters.weighted_diff.sum() / sum_slip
fish_l2 = iters.w_diff_sq.sum() / sum_slip

# %%
fish_l1_like = np.exp(kappa * np.cos(fish_l1) )
fish_l2_like = np.exp(kappa * (np.cos(fish_l2)**0.5 ) )

# %%
fish_l1n_like = fish_l1_like / fish_l1_like.max()
fish_l2n_like = fish_l2_like / fish_l2_like.max()

# %%
fish_l1_like.hist(bins=50)

# %%
fish_l1n_like.hist(bins=50)

# %%
fish_l1.hist(bins=50)

# %%
fish_l2.hist(bins=50)

# %%
fish_l2_like.hist(bins=50)

# %%
fish_l2n_like.hist(bins=50)

# %%
rand_filter = np.random.random(n_trials)

# %%
fishtrap_l1 = fish_l1n_like[fish_l1n_like >= rand_filter]
fishtrap_l2 = fish_l2n_like[fish_l2n_like >= rand_filter]

# %%
fishtrap_l1.hist(bins=50)

# %%
fishtrap_l2.hist(bins=50)

# %%
iters_txx = iters.txx.mean()
iters_tyy = iters.tyy.mean()
iters_txy = iters.txy.mean()

# %%
txx_l1_keep = iters_txx[fishtrap_l1.index]
txy_l1_keep = iters_txy[fishtrap_l1.index]
tyy_l1_keep = iters_tyy[fishtrap_l1.index]

txx_l2_keep = iters_txx[fishtrap_l2.index]
txy_l2_keep = iters_txy[fishtrap_l2.index]
tyy_l2_keep = iters_tyy[fishtrap_l2.index]

# %%
#tau_posteriors = pd.concat([txx_keep, tyy_keep, txy_keep], axis=1,
#                           names=['txx', 'tyy', 'txy'])

#tau_posteriors.to_csv('../results/tau_posteriors.csv', index=False)

# %%
#tau_posteriors

# %%
len(txx_l2_keep)
# Out:
# 4499

# %%
def make_xy_stress_tensor(s_xx=0, s_yy=0, s_xy=0):
    T = np.matrix([[s_xx, s_xy],
                   [s_xy, s_yy]])
    
    return T

def get_princ_stress_dirs(T):
    vals, vecs = hsp.sorted_eigens(T)
    vecs = np.array(vecs)
    
    max_x = vecs[0,1] * vals[1]
    max_y = vecs[1,1] * vals[1]
    min_x = vecs[0,0] * vals[0]
    min_y = vecs[1,0] * vals[0]
    
    return max_x, max_y, min_x, min_y


def calc_princ_stress_dirs_from_tensor(s_xx=0, s_yy=0, s_xy=0):
    T = make_xy_stress_tensor(s_xx=s_xx, s_yy=s_yy, s_xy=s_xy)
    
    max_x, max_y, min_x, min_y = get_princ_stress_dirs(T)
    return max_x, max_y, min_x, min_y

# %%
X1a = []
Y1a = []
x1a = []
y1a = []


for i in np.arange(len(txx_l1_keep.values)):
    
    XX, YY, xx, yy = calc_princ_stress_dirs_from_tensor(txx_l1_keep.values[i],
                                                        tyy_l1_keep.values[i],
                                                        txy_l1_keep.values[i])
    #print(XX,YY)
    
    X1a.append(XX)
    Y1a.append(YY)
    x1a.append(xx)
    y1a.append(yy)

X1a = np.array(X1a)
Y1a = np.array(Y1a)
x1a = np.array(x1a)
y1a = np.array(y1a)

# %%
X2a = []
Y2a = []
x2a = []
y2a = []


for i in np.arange(len(txx_l2_keep.values)):
    
    XX, YY, xx, yy = calc_princ_stress_dirs_from_tensor(txx_l2_keep.values[i],
                                                        tyy_l2_keep.values[i],
                                                        txy_l2_keep.values[i])
    #print(XX,YY)
    
    X2a.append(XX)
    Y2a.append(YY)
    x2a.append(xx)
    y2a.append(yy)

X2a = np.array(X2a)
Y2a = np.array(Y2a)
x2a = np.array(x2a)
y2a = np.array(y2a)

# %%
figure(1)

scatter(X1a, Y1a, c='r',
        s=7, lw=0, alpha=0.2)
#colorbar()
scatter(-X1a, -Y1a, c='r',
        s=7, lw=0, alpha=0.2)
axis('equal')

figure(2)
scatter(x1a, y1a, c='b',
        s=7, lw=0, alpha=0.2)
#colorbar()
scatter(-x1a, -y1a, c='b',
        s=7, lw=0, alpha=0.2)
axis('equal')

figure(3)

scatter(X2a, Y2a, c='r',
        s=7, lw=0, alpha=0.2)
#colorbar()
scatter(-X2a, -Y2a, c='r',
        s=7, lw=0, alpha=0.2)
axis('equal')

figure(4)
scatter(x2a, y2a, c='b',
        s=7, lw=0, alpha=0.2)
#colorbar()
scatter(-x2a, -y2a, c='b',
        s=7, lw=0, alpha=0.2)
axis('equal')

show()

# %%
fish_l1_like.max()
# Out:
# 3673.6765850563283

# %%
fish_l1n_like[fish_l1n_like==1.0]
# Out:
# iter
# 7376    1
# Name: weighted_diff, dtype: float64

# %%
l1_best = search_df[search_df.iter == 305]

# %%
scatter(lms.rake_deg, l1_best.tau_rake, c=lms.slp_am_m,
        lw=0, alpha=0.5)

# %%
figure(1)

scatter(-lms.lon_deg, -lms.depth_km, c=lms.rake_deg,
        vmin=-180, vmax=180,
        s=lms.slp_am_m*10,
        lw=0, alpha=0.5)
colorbar()


figure(2)

scatter(-lms.lon_deg, -lms.depth_km, c=l1_best.tau_rake,
        vmin=-180, vmax=180,
        s=lms.slp_am_m*10,
        lw=0, alpha=0.5)
colorbar()

figure(3)

scatter(-lms.lon_deg, -lms.depth_km, 
        c=(lms.rake_deg.values-l1_best.tau_rake.values),
        vmin=-180, vmax=180,
        s=lms.slp_am_m*10,
        lw=0, alpha=0.5)
colorbar()

show()

# %%
hsp.get_rake_from_shear_components(strike_shear=0, dip_shear=1)
# Out:
# 90.0

# %%
np.degrees( np.arctan2(0, 1) )
# Out:
# 0.0

# %%
def get_rake_from_shear_components(strike_shear=0, dip_shear=0):
    return np.degrees( np.arctan2(dip_shear, - strike_shear))

# %%
get_rake_from_shear_components(strike_shear=-1, dip_shear=-1)
# Out:
# -45.0

# %%
# !mvim /Users/itchy/school/halfspace/halfspace/projections.py

# %%
lms.columns
# Out:
# Index([u'lat_deg', u'lon_deg', u'depth_km', u'slp_strk_m', u'slp_ddip_m', u'slp_am_m', u'strike_deg', u'dip_deg', u'rake_deg', u'xx_stress', u'yy_stress', u'xy_stress', u'zz_stress', u'xz_stress', u'yz_stress'], dtype='object')

# %%
lms[['slp_strk_m', 'slp_ddip_m', 'rake_deg']]
# Out:
#     slp_strk_m  slp_ddip_m    rake_deg
# 0       1.2616      0.1872  171.559864
# 1       1.4475      0.1238  175.111573
# 2       1.4525      0.0435  178.284598
# 3       1.2829     -0.0000 -180.000000
# 4       1.0385     -0.0000 -180.000000
# 5       0.7792     -0.0000 -180.000000
# 6       0.5151     -0.0000 -180.000000
# 7       0.2432     -0.0000 -180.000000
# 8       2.0044      0.1660  175.265694
# 9       2.2840      0.1032  177.412914
# 10      2.3488      0.0210  179.487747
# 11      2.1460     -0.0000 -180.000000
# 12      1.7864     -0.0000 -180.000000
# 13      1.3603     -0.0000 -180.000000
# 14      0.9005     -0.0000 -180.000000
# 15      0.4226     -0.0000 -180.000000
# 16      2.1780      0.4900  167.320868
# 17      2.3693      0.3968  170.492586
# 18      2.4270      0.2074  175.115639
# 19      2.2521      0.0481  178.776472
# 20      1.9087     -0.0000 -180.000000
# 21      1.4687     -0.0000 -180.000000
# 22      0.9700     -0.0000 -180.000000
# 23      0.4491     -0.0000 -180.000000
# 24      2.1927      1.2171  150.966699
# 25      2.2186      1.0770  154.106150
# 26      2.1590      0.7543  160.741877
# 27      1.9409      0.3679  169.266851
# 28      1.6065      0.0960  176.580229
# 29      1.2088     -0.0000 -180.000000
# 30      0.7779     -0.0000 -180.000000
# 31      0.3484     -0.0000 -180.000000
# 32      2.3109      1.8975  140.610286
# 33      2.2274      1.7746  141.455189
# 34      2.0141      1.4502  144.245213
# 35      1.6677      0.9338  150.754103
# 36      1.2563      0.4192  161.547266
# 37      0.8503      0.0971  173.485329
# 38      0.4911     -0.0000 -180.000000
# 39      0.1977     -0.0000 -180.000000
# 40      2.6079      2.0012  142.498784
# 41      2.5125      2.0306  141.054891
# 42      2.1694      1.9266  138.392372
# 43      1.6577      1.5004  137.851456
# 44      1.0999      0.8734  141.547888
# 45      0.6117      0.3271  151.864835
# 46      0.2650      0.0486  169.607656
# 47      0.0715     -0.0000 -180.000000
# 48      2.9934      1.2851  156.765613
# 49      2.9283      1.6332  150.850292
# 50      2.5038      1.9565  141.995495
# 51      1.8596      1.8254  135.531739
# 52      1.1568      1.2553  132.661581
# 53      0.5548      0.5853  133.467587
# 54      0.1662      0.1409  139.709596
# 55      0.0087     -0.0000 -180.000000
# 56      3.2034      0.3741  173.339046
# 57      3.1784      1.0064  162.430270
# 58      2.7716      1.7002  148.473537
# 59      2.1008      1.8591  138.492823
#            ...         ...         ...
#
# [702 rows x 3 columns]
