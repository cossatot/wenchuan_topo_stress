# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
from statsmodels.sandbox.tools import pca
from statsmodels.sandbox.tools.cross_val import LeaveOneOut

# %%
from sklearn.decomposition import PCA as skPCA
from sklearn.decomposition import FactorAnalysis as skFA

# %%
repo_dir = '/Users/itchy/school/topo_stress/wenchuan/'
slip_dir = repo_dir + 'slip_models/'
bf_file = slip_dir + 'aggregates/beich_shallow_slip.csv'

# %%
bf = pd.read_csv(bf_file, index_col=0)

# %%
bf_med_pca_cols = ['along_strike_km', 'depth_m', 'med_strike', 'med_dip', 'slip_mag_med',
                   #'xx_stress', 'yy_stress', 'zz_stress', 'xy_stress', 'xz_stress', 'yz_stress',
                   'sig_nn_med', 'tau_dd_med', 'tau_ss_med']

# %%
bf_med_pca = bf[bf_med_pca_cols]

# %%
bf_med_pca
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1408 entries, 0 to 1407
# Data columns (total 8 columns):
# along_strike_km    1408  non-null values
# depth_m            1408  non-null values
# med_strike         1408  non-null values
# med_dip            1408  non-null values
# slip_mag_med       1408  non-null values
# sig_nn_med         1408  non-null values
# tau_dd_med         1408  non-null values
# tau_ss_med         1408  non-null values
# dtypes: float64(8)

# %%
scatter(bf.along_strike_km, bf.depth_m, c=bf.slip_mag_med, lw=0)

# %%
scatter(bf.along_strike_km, bf.depth_m, c=bf.sig_nn_med, lw=0)

# %%
scatter(bf.along_strike_km, bf.depth_m, c=bf.tau_ss_med, lw=0)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x10c49dab8>

# %%
scatter(bf.along_strike_km, bf.depth_m, c=bf.med_strike, lw=0)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x10c1ed4d0>

# %%
scatter(bf.along_strike_km, bf.depth_m, c=bf.med_dip, lw=0)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x10cc03e60>

# %%
print  smf.quantreg('slip_mag_med ~ sig_nn_med + tau_dd_med + tau_ss_med + med_dip + depth_m + along_strike_km', bf).fit(q=0.5).summary2()
# Out:
#                         Results: QuantReg
# ================================================================
# Model:                 QuantReg      Pseudo R-squared:    0.238
# Dependent Variable:    slip_mag_med  AIC:                 nan
# No. Observations:      1408          BIC:                 nan
# Df Model:              6             Log-Likelihood:      nan
# Df Residuals:          1401          F-statistic:         nan
# R-squared:             nan           Prob (F-statistic):  nan
# Adj. R-squared:        nan           Scale:               1.0000
# ----------------------------------------------------------------
#                  Coef.  Std.Err.    t     P>|t|   [0.025  0.975]
# ----------------------------------------------------------------
# Intercept        4.7044   0.6280   7.4907 0.0000  3.4724  5.9363
# sig_nn_med       0.0137   0.0074   1.8428 0.0656 -0.0009  0.0282
# tau_dd_med       0.0506   0.0088   5.7288 0.0000  0.0333  0.0679
# tau_ss_med      -0.1689   0.0134 -12.6510 0.0000 -0.1951 -0.1427
# med_dip         -0.0147   0.0043  -3.4009 0.0007 -0.0232 -0.0062
# depth_m          0.0002   0.0000  18.7545 0.0000  0.0002  0.0002
# along_strike_km -0.0060   0.0009  -6.8879 0.0000 -0.0076 -0.0043
# ----------------------------------------------------------------
# Omnibus:             65.211       Durbin-Watson:          0.358
# Prob(Omnibus):       0.000        Jarque-Bera (JB):       88.383
# Skew:                0.439        Prob(JB):               0.000
# Kurtosis:            3.858        Condition No.:          155035
# ================================================================
# * The condition number is large (2e+05). This might indicate
# strong multicollinearity or other numerical problems.

# %%
bf_med_ols = smf.ols('slip_mag_med ~ sig_nn_med + tau_dd_med + tau_ss_med + med_dip + depth_m + along_strike_km',
                     bf).fit()

print bf_med_ols.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           slip_mag_med   R-squared:                       0.405
# Model:                            OLS   Adj. R-squared:                  0.402
# Method:                 Least Squares   F-statistic:                     158.9
# Date:                Wed, 04 Sep 2013   Prob (F-statistic):          5.11e-154
# Time:                        09:39:44   Log-Likelihood:                -2488.7
# No. Observations:                1408   AIC:                             4991.
# Df Residuals:                    1401   BIC:                             5028.
# Df Model:                           6
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Intercept           6.4984      0.607     10.708      0.000         5.308     7.689
# sig_nn_med         -0.0028      0.007     -0.389      0.697        -0.017     0.011
# tau_dd_med          0.0448      0.009      5.255      0.000         0.028     0.062
# tau_ss_med         -0.1765      0.013    -13.682      0.000        -0.202    -0.151
# med_dip            -0.0266      0.004     -6.362      0.000        -0.035    -0.018
# depth_m             0.0002   8.99e-06     17.247      0.000         0.000     0.000
# along_strike_km    -0.0089      0.001    -10.654      0.000        -0.011    -0.007
# ==============================================================================
# Omnibus:                       53.932   Durbin-Watson:                   0.424
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               65.303
# Skew:                           0.423   Prob(JB):                     6.60e-15
# Kurtosis:                       3.631   Cond. No.                     1.55e+05
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.55e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
print smf.ols('dip_slip_median ~ sig_nn_med + tau_dd_med + med_dip + depth_m + along_strike_km',
                     bf).fit().summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        dip_slip_median   R-squared:                       0.372
# Model:                            OLS   Adj. R-squared:                  0.370
# Method:                 Least Squares   F-statistic:                     166.0
# Date:                Wed, 04 Sep 2013   Prob (F-statistic):          8.26e-139
# Time:                        09:39:46   Log-Likelihood:                -2363.1
# No. Observations:                1408   AIC:                             4738.
# Df Residuals:                    1402   BIC:                             4770.
# Df Model:                           5
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Intercept           6.9604      0.555     12.550      0.000         5.872     8.048
# sig_nn_med         -0.0203      0.007     -3.116      0.002        -0.033    -0.008
# tau_dd_med          0.0304      0.008      3.925      0.000         0.015     0.046
# med_dip            -0.0285      0.004     -7.462      0.000        -0.036    -0.021
# depth_m             0.0001   8.01e-06     17.933      0.000         0.000     0.000
# along_strike_km    -0.0081      0.001    -10.907      0.000        -0.010    -0.007
# ==============================================================================
# Omnibus:                      195.835   Durbin-Watson:                   0.281
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              339.248
# Skew:                           0.896   Prob(JB):                     2.15e-74
# Kurtosis:                       4.604   Cond. No.                     1.55e+05
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.55e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
scatter(bf.dip_slip_median, bf.strike_slip_median, c=bf.sig_nn_med, lw=0)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x10cc749e0>

# %%
scale = lambda x: (x - x.mean()) / x.std()
    
def OLSreg(y, Xmat):
    return sm.OLS(y, sm.add_constant(Xmat, prepend = True)).fit()

# %%
pca_model = skPCA(n_components=8)

# %%
slip_pca_cor_fit = skPCA(n_components=8).fit(bf_med_pca.corr() )

# %%
bar(arange(8) + 0.5, slip_pca_cor_fit.explained_variance_ratio_.cumsum() )
ylim([0,1])
xlabel('No. principal components')
ylabel('cumulative variance explained')
grid(axis = 'y', ls = '-', lw=1, color = 'white')
show()

# %%
bf_pca_norm = bf_med_pca.apply(scale)

# %%
bf_pca_norm.head()
# Out:
#    along_strike_km   depth_m  med_strike   med_dip  slip_mag_med  sig_nn_med  \
# 0        -1.711871 -1.626401   -2.401484  1.930591     -1.162593    0.022540
# 1        -1.672517 -1.626401   -0.344829  1.432835     -1.162593    0.443221
# 2        -1.633164 -1.626401    0.152395  1.755804     -1.162593    0.166811
# 3        -1.593811 -1.626401    0.042226  1.624958     -1.162593    0.247859
# 4        -1.554457 -1.626401   -6.232994  1.268900     -0.974401    0.001866
#
#    tau_dd_med  tau_ss_med
# 0    0.425412    0.400445
# 1   -3.089993    0.774812
# 2   -2.801478    1.004306
# 3   -2.846725    1.034222
# 4    3.085109    1.296050

# %%
bf_med_pca.head()
# Out:
#    along_strike_km  depth_m  med_strike    med_dip  slip_mag_med  sig_nn_med  \
# 0                0   -16000  134.883307  88.438766      0.000000   42.755205
# 1                4   -16000  207.382830  80.988729      0.000000   49.243976
# 2                8   -16000  224.910571  85.822683      0.000000   44.980506
# 3               12   -16000  221.026991  83.864287      0.000000   46.230620
# 4               16   -16000   -0.181985  78.535074      0.345833   42.436327
#
#    tau_dd_med  tau_ss_med
# 0   -3.454271   -1.082570
# 1  -21.293002    0.338075
# 2  -19.828950    1.208959
# 3  -20.058554    1.322483
# 4   10.042219    2.316071

# %%
slip_pca_norm_fit = skPCA(n_components=8).fit(bf_pca_norm.corr() )
slip_pca_fit_1_comp = skPCA(n_components=1).fit(bf_pca_norm.corr())

# %%
bar(arange(8) + 0.5, slip_pca_norm_fit.explained_variance_ratio_.cumsum() )
ylim([0,1])
xlabel('No. principal components')
ylabel('cumulative variance explained')
grid(axis = 'y', ls = '-', lw=1, color = 'white')
show()

# %%
bf_exog = bf_med_pca[['along_strike_km', 'depth_m', 'med_strike', 'med_dip',
                   #'xx_stress', 'yy_stress', 'zz_stress', 'xy_stress', 'xz_stress', 'yz_stress',
                   'sig_nn_med', 'tau_dd_med', 'tau_ss_med']].apply(scale)

# %%
exog_1_pca = -scale( skPCA(n_components=1).fit_transform(bf_exog) )

# %%
scatter(exog_1_pca, bf.slip_mag_med)

# %%
scatter(bf.sig_nn_med, exog_1_pca)

# %%
exog_all_pca_fit = skPCA(n_components=7).fit(bf_exog.corr())

# %%
bar(arange(7) + 0.5, exog_all_pca_fit.explained_variance_ratio_.cumsum() )
ylim([0,1])
xlabel('No. principal components')
ylabel('cumulative variance explained')
grid(axis = 'y', ls = '-', lw=1, color = 'white')
show()

# %% [markdown]
# ###seismic potency calcs

# %% [markdown]
# median slip model

# %%
bf.slip_mag_med.sum() * 4
# Out:
# 12032.516118394753

# %%
bf.slip_mag_mean.sum() * 4
# Out:
# 13075.733226897906

# %%
bf.dip_slip_median.sum() * 4
# Out:
# 9018.1455011015241

# %% [markdown]
# feng dip slip

# %%
bf.f_dip_slip.sum() * 4
# Out:
# 8824.831667564169

# %%
bf.dip_slip_median.sum() / bf.f_dip_slip.sum()
# Out:
# 1.0219056680987904
