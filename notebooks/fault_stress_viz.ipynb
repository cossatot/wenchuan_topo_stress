# %%
# %matplotlib inline
# %config inline_backend.figure_format = 'retina'

# %%
import sys

sys.path.append('../tect_stress/scripts/')

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import numpy as np
from matplotlib import gridspec
import json
import halfspace.projections as hsp
import stress_comps_vectorized as scv

# %%
pd.set_option('display.max_columns',60)

# %% [markdown]
# ### 'most likely' params

# %%
# highest density from nd-histogram
hd = {'phi': 0.13211207372221404, 'txx': 0.34018624795451669, 'tyy': 0.15102153053030518, 
      'txy': -0.04660039525137305, 'mu': 0.078526668165911889}

# %%
rho = 2700
g = 9.81

# %% [markdown]
# ## Zhang

# %%
zz = pd.read_csv('../slip_models/zhang/lms_stress_slip.csv', index_col=0)

# shallowest level is above top of halfspace; trim here
zz = zz[zz.depth_km > 1.4993]

# %%
zz.describe()
# Out:
#           lat_deg     lon_deg    depth_km  x_local_km  y_local_km  \
# count  663.000000  663.000000  663.000000  663.000000  663.000000
# mean    31.754093  104.213075   15.115177   39.628959   19.061312
# std      0.451223    0.589067    8.171296   27.512243   10.205351
# min     30.950800  103.199500    1.683900    2.000000    1.944400
# 25%     31.385400  103.751150    7.624900   14.218800   10.000000
# 50%     31.695400  104.080000   14.160600   34.531200   18.450000
# 75%     32.140450  104.692050   21.665800   58.000000   26.650000
# max     32.634100  105.381000   29.544200  106.000000   38.950000
#
#              utm_lon         utm_lat      x_pixel     y_pixel     z_pixel  \
# count     663.000000      663.000000   663.000000  663.000000  663.000000
# mean   425206.676978  3513598.440548  1263.574242  584.265731   13.615177
# std     56053.069290    49671.756033    66.079224   58.556491    8.171296
# min    328251.274702  3425281.335096  1149.276528  480.151437    0.183900
# 25%    381236.636468  3472966.311276  1211.739326  536.365775    6.124900
# 50%    412576.561760  3507131.102222  1248.684991  576.641587   12.660600
# 75%    470967.998782  3556050.483272  1317.520844  634.311127   20.165800
# max    535751.036303  3610777.759235  1393.891556  698.827414   28.044200
#
#         zz_stress   xx_stress   yy_stress   xz_stress   xy_stress   yz_stress  \
# count  663.000000  663.000000  663.000000  663.000000  663.000000  663.000000
# mean    48.967079   32.161874   38.647450    7.794621    0.817347   -5.505998
# std     15.651889    8.825546    4.572073    4.167146    0.930655    3.345749
# min     19.372076   10.976253   27.866691   -4.100890   -1.819416  -15.906840
# 25%     35.255938   24.317239   34.470789    4.700538    0.115556   -8.395139
# 50%     44.382175   33.049972   38.696064    7.661354    0.776053   -5.056202
# 75%     65.383697   39.147966   43.082391   11.041263    1.586147   -3.133328
# max     80.329873   47.129890   49.766906   17.493517    3.141727    3.875399
#
#            sig_nn      tau_dd      tau_ss      tau_cs  slp_strk_m  slp_ddip_m  \
# count  663.000000  663.000000  663.000000  663.000000  663.000000  663.000000
# mean    49.148501   -8.202331   -2.038130  -19.896145    1.564992    1.300595
# std     16.596422    4.918007    3.320325    8.693494    1.491859    1.658865
# min     20.916169  -20.946713  -10.406976  -37.054072   -0.000000   -0.000000
# 25%     30.009007   -8.437578   -6.058538  -27.443823    0.421050    0.703975
# 50%     44.516849   -5.269808   -3.649741  -20.058131    2.034050    1.621500
# 75%     62.588115   -2.617757   -0.399679  -10.363510    3.181450    3.068650
# max     74.383123    3.650190    3.431334   -3.148237    7.028500    7.015400
#
#          slp_am_m  strike_deg     dip_deg    rake_deg
# count  340.000000  340.000000  340.000000  340.000000
# mean     3.147480  224.588235   56.270588   32.757394
# std      2.113524    5.507397   17.141706   47.060743
# min      0.000000  222.000000   33.000000 -180.000000
# 25%      1.401850  222.000000   47.000000   12.409653
# 50%      3.024250  222.000000   47.000000   39.577305
# 75%      4.513275  222.000000   70.000000   61.277895
# max      9.186700  245.000000   80.000000   90.000000
#
# [8 rows x 26 columns]

# %%
plt.scatter(np.sqrt(zz.yy_stress**2 + zz.xx_stress**2)/zz.zz_stress, -zz.depth_km,
            c=zz.dip_deg, lw=0)

plt.colorbar()

plt.show()

# %%
zz['S_tau_s'] = scv.strike_shear( strike=zz.strike_deg, dip=zz.dip_deg, 
                                 rho = rho, g = g, mxx = zz.xx_stress*1e6,
                                 myy = zz.yy_stress*1e6, mxy=zz.xy_stress*1e6,
                                 mzz=zz.zz_stress*1e6, mxz=zz.xz_stress*1e6,
                                 myz=zz.yz_stress*1e6, txx=hd['txx'], tyy=hd['tyy'], txy=hd['txy'],
                                 depth=zz.depth_km*1000) * 1e-6

zz['S_tau_d'] = scv.dip_shear( strike=zz.strike_deg, dip=zz.dip_deg, 
                                 rho = rho, g = g, mxx = zz.xx_stress*1e6,
                                 myy = zz.yy_stress*1e6, mxy=zz.xy_stress*1e6,
                                 mzz=zz.zz_stress*1e6, mxz=zz.xz_stress*1e6,
                                 myz=zz.yz_stress*1e6, txx=hd['txx'], tyy=hd['tyy'], txy=hd['txy'],
                                 depth=zz.depth_km*1000) * 1e-6

zz['sig_n_eff'] = scv.eff_normal_stress( strike=zz.strike_deg, dip=zz.dip_deg, 
                                 rho = rho, g = g, mxx = zz.xx_stress*1e6,
                                 myy = zz.yy_stress*1e6, mxy=zz.xy_stress*1e6,
                                 mzz=zz.zz_stress*1e6, mxz=zz.xz_stress*1e6,
                                 myz=zz.yz_stress*1e6, txx=hd['txx'], tyy=hd['tyy'], txy=hd['txy'],
                                 depth=zz.depth_km*1000, phi=hd['phi'])  * 1e-6

zz['S_tau_mag'] = np.sqrt(zz.S_tau_s**2 + zz.S_tau_d**2)

zz['S_rake'] = hsp.get_rake_from_shear_components(strike_shear=zz.S_tau_s, dip_shear=zz.S_tau_d)

# %%
zz['cfs'] = zz.S_tau_mag - hd['mu'] * zz.sig_n_eff

# %%
zz.describe()
# Out:
#           lat_deg     lon_deg    depth_km  x_local_km  y_local_km  \
# count  663.000000  663.000000  663.000000  663.000000  663.000000
# mean    31.754093  104.213075   15.115177   39.628959   19.061312
# std      0.451223    0.589067    8.171296   27.512243   10.205351
# mean   462.980632   48.629438  121.705857   12.273112
# std    234.603622   29.893987   33.907605   14.016178
# min     75.938454    0.738126 -174.632584  -13.077889
# 25%    260.047618   23.713449  116.554478    1.364057
# 50%    432.109773   46.063079  120.162265    9.332790
# 75%    659.585596   71.882293  136.922056   19.163392
# max    901.414076  114.484571  173.464687   50.230893
#
# [8 rows x 32 columns]

# %%
plt.plot()

# %%
rot_p = json.load( open('../slip_models/wench_rot_params.json') )

rot_p
# Out:
# {u'rot_angle': 0.7874348431086999,
#  u'strike': 224.88330684832536,
#  u'x0': 321063.31049255736,
#  u'y0': 3398621.1564545436}

# %%
zz['trace_dist_km'], zz['along_strike_km'] = hsp.rotate_pts_2d(zz.utm_lon, zz.utm_lat,
                                                               rot_p['x0'], rot_p['y0'],
                                                               rot_p['rot_angle']) * 0.001

# %%
zz.dip_deg.unique()
# Out:
# array([ 80.,  70.,  60.,  47.,  33.])

# %%
bf = zz[zz.dip_deg != 33.]
pf = zz[zz.dip_deg == 33.]

b1 = zz[zz.dip_deg ==80.]
b2 = zz[zz.dip_deg ==70.]
b3 = zz[zz.dip_deg ==60.]
b4 = zz[zz.dip_deg ==47.]

# %%
pf_pslip = pf.pivot('y_local_km', 'x_local_km', values='slp_am_m')
b1_pslip = b1.pivot('y_local_km', 'x_local_km', values='slp_am_m')
b2_pslip = b2.pivot('y_local_km', 'x_local_km', values='slp_am_m')
b3_pslip = b3.pivot('y_local_km', 'x_local_km', values='slp_am_m')
b4_pslip = b4.pivot('y_local_km', 'x_local_km', values='slp_am_m')

# %%
pf_pslip
# Out:
# x_local_km      2       6       10      14      18      22      26      30  \
# y_local_km
# 6           1.2241  2.0328  2.2635  1.9042  1.3450  1.0061  0.8282  0.8826
# 10          1.0317  1.8054  1.9552  1.5982  1.0867  0.6903  0.4749  0.4902
# 14          0.7950  1.3687  1.4380  1.1295  0.7094  0.3703  0.1993  0.2250
# 18          0.4625  0.7799  0.7886  0.5740  0.3069  0.1120  0.0322  0.0585
# 22          0.1370  0.2419  0.2351  0.1466  0.0496  0.0000  0.0000  0.0000
# 26          0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 30          0.0000  0.0000  0.0000  0.0036  0.0081  0.0071  0.0016  0.0062
# 34          0.0000  0.0132  0.0303  0.0414  0.0435  0.0332  0.0192  0.0084
#
# x_local_km      34      38      42      46
# y_local_km
# 6           1.0213  1.0614  0.9786  0.6692
# 10          0.6689  0.8245  0.7835  0.5034
# 14          0.4044  0.5932  0.6247  0.4106
# 18          0.2028  0.3874  0.4627  0.3133
# 22          0.0806  0.2179  0.2848  0.1875
# 26          0.0381  0.1152  0.1502  0.0897
# 30          0.0304  0.0682  0.0773  0.0420
# 34          0.0205  0.0373  0.0402  0.0259
#
# [8 rows x 12 columns]

# %%
pf_depth = pf.pivot('y_local_km', 'x_local_km', values='depth_km')
b1_depth = b1.pivot('y_local_km', 'x_local_km', values='depth_km')
b2_depth = b2.pivot('y_local_km', 'x_local_km', values='depth_km')
b3_depth = b3.pivot('y_local_km', 'x_local_km', values='depth_km')
b4_depth = b4.pivot('y_local_km', 'x_local_km', values='depth_km')

pf_along_km = pf.pivot('y_local_km', 'x_local_km', values='along_strike_km')
b1_along_km = b1.pivot('y_local_km', 'x_local_km', values='along_strike_km')
b2_along_km = b2.pivot('y_local_km', 'x_local_km', values='along_strike_km')
b3_along_km = b3.pivot('y_local_km', 'x_local_km', values='along_strike_km')
b4_along_km = b4.pivot('y_local_km', 'x_local_km', values='along_strike_km')

# %%
## trying this again with global coord values

#pf_depth = pf.pivot('y_local_km', 'x_local_km', values='depth_km')
#b1_depth = b1.pivot('y_local_km', 'x_local_km', values='depth_km')
#b2_depth = b2.pivot('y_local_km', 'x_local_km', values='depth_km')
#b3_depth = b3.pivot('y_local_km', 'x_local_km', values='depth_km')
#b4_depth = b4.pivot('y_local_km', 'x_local_km', values='depth_km')

#pf_along_km = pf.pivot('y_local_km', 'x_local_km', values='along_strike_km')
#b1_along_km = b1.pivot('y_local_km', 'x_local_km', values='along_strike_km')
#b2_along_km = b2.pivot('y_local_km', 'x_local_km', values='along_strike_km')
#b3_along_km = b3.pivot('y_local_km', 'x_local_km', values='along_strike_km')
#b4_along_km = b4.pivot('y_local_km', 'x_local_km', values='along_strike_km')

# %%
plt.figure()

plt.pcolormesh( b1_along_km.values, b1_depth.values, b1_pslip.values)
plt.gca().invert_yaxis()
plt.gca().invert_xaxis()
plt.axis('equal')

plt.show()

# %%
plt.figure()

plt.pcolormesh( b1_along_km.values, b1_depth.values, b1_pslip.values)
plt.pcolormesh( b2_along_km.values, b2_depth.values, b2_pslip.values)
plt.pcolormesh( b3_along_km.values, b3_depth.values, b3_pslip.values)
plt.pcolormesh( b4_along_km.values, b4_depth.values, b4_pslip.values)

plt.gca().invert_yaxis()
plt.gca().invert_xaxis()
plt.axis('equal')

plt.show()

# %%
pf_nn = pf.pivot('y_local_km', 'x_local_km', values='sig_nn')
b1_nn = b1.pivot('y_local_km', 'x_local_km', values='sig_nn')
b2_nn = b2.pivot('y_local_km', 'x_local_km', values='sig_nn')
b3_nn = b3.pivot('y_local_km', 'x_local_km', values='sig_nn')
b4_nn = b4.pivot('y_local_km', 'x_local_km', values='sig_nn')

# %%
plt.figure()

plt.pcolormesh( b1_along_km.values, b1_depth.values, b1_nn.values, 
               vmax=zz.sig_nn.max(), vmin = zz.sig_nn.min())
plt.pcolormesh( b2_along_km.values, b2_depth.values, b2_nn.values, 
               vmax=zz.sig_nn.max(), vmin = zz.sig_nn.min())
plt.pcolormesh( b3_along_km.values, b3_depth.values, b3_nn.values, 
               vmax=zz.sig_nn.max(), vmin = zz.sig_nn.min())
plt.pcolormesh( b4_along_km.values, b4_depth.values, b4_nn.values, 
               vmax=zz.sig_nn.max(), vmin = zz.sig_nn.min())

plt.colorbar()

#plt.quiver(b1.along_strike_km.values, b1.depth_km.values, 
#           b1.tau_dd.values, -b1.tau_ss.values)

plt.xlim([0,350])
plt.gca().invert_yaxis()
plt.gca().invert_xaxis()
plt.axis('equal')

plt.show()

# %%
cubeyf = np.loadtxt('/Users/itchy/Desktop/cubeyf.csv', delimiter=',')

# %%
cubeyf.shape
# Out:
# (256, 3)

# %%
cube_yf = mpl.colors.ListedColormap(cubeyf)

# %%
b1.depth_km.unique()
# Out:
# array([  1.9696,   5.9088,   9.8481,  13.7873,  17.7265,  21.6658,
#         25.605 ,  29.5442])

# %%
b4.depth_km.unique()
# Out:
# array([  1.4993,   4.4978,   7.4964,  10.4949,  13.4935,  16.492 ,
#         19.4906,  22.4891,  25.4877,  28.4862])

# %% [markdown]
# ## Shen

# %%
sb = pd.read_csv('../slip_models/shen/shen_beich_topo_stress.csv', index_col=0)
sp = pd.read_csv('../slip_models/shen/shen_peng_topo_stress.csv', index_col=0)

# %%
sb.iloc[0]
# Out:
# length_km            3.8142
# width_km                  4
# depth_km              3.973
# dip                   96.66
# strike               222.99
# lat                 32.6194
# lon                105.4699
# s_slip_m            1.43708
# d_slip_m            1.25042
# easting_utm48      544083.8
# northing_utm48      3609192
# segment            beichuan
# xx_stress          11.64547
# yy_stress          29.36479
# zz_stress          22.78684
# xy_stress          1.066334
# xz_stress         0.2953741
# yz_stress          1.001915
# x_pixel            1403.715
# y_pixel            696.9584
# z_pixel               2.122
# sig_nn             18.98129
# tau_dd            0.9114751
# tau_ss            -8.812328
# tau_cs            -2.529431
# Name: 1, dtype: object

# %%
sb['trace_dist_km'], sb['along_strike_km'] = hsp.rotate_pts_2d(sb.easting_utm48, 
                                                               sb.northing_utm48,
                                                               rot_p['x0'], rot_p['y0'],
                                                               rot_p['rot_angle']) * 0.001

sp['trace_dist_km'], sp['along_strike_km'] = hsp.rotate_pts_2d(sp.easting_utm48, 
                                                               sp.northing_utm48,
                                                               rot_p['x0'], rot_p['y0'],
                                                               rot_p['rot_angle']) * 0.001

# %%
sb_flat = sb[sb.dip == 0]

sb = sb[sb.dip > 0]

# %%
plt.scatter(sb.easting_utm48, sb.northing_utm48, c=sb.dip)
plt.colorbar()
plt.axis('equal')
plt.show()

# %%
sb_flat.head()
# Out:
#        length_km  width_km  depth_km  dip  strike      lat       lon  \
# index
# 583       5.9773         4   19.1896    0  233.76  31.2968  103.5020
# 584       6.2558         4   19.1896    0  233.64  31.3250  103.4759
# 585       6.4078         4   19.1896    0  233.57  31.3535  103.4502
# 586       6.5553         4   19.1896    0  233.52  31.3820  103.4246
# 587       6.6988         4   19.1896    0  233.46  31.4105  103.3989
#
#        s_slip_m  d_slip_m  easting_utm48  northing_utm48   segment  xx_stress  \
# index
# 583     1.10120   1.63732  357429.150108  3463463.893401  beichuan  46.600850
# 584     0.89738   1.18633  354988.058480  3466623.868030  beichuan  48.142653
# 585     0.69372   0.80180  352586.989759  3469817.198535  beichuan  49.397475
# 586     0.50467   0.52962  350196.930063  3473011.012470  beichuan  50.393240
# 587     0.34585   0.37642  347798.858246  3476205.580758  beichuan  51.216429
#
#        yy_stress  zz_stress  xy_stress  xz_stress  yz_stress      x_pixel  \
# index
# 583    44.726520  66.522207   1.854355   9.809901  -9.014937  1183.673420
# 584    46.035011  69.274784   1.684920   9.862812  -7.942423  1180.795692
# 585    47.357618  71.811904   1.562291   9.943187  -6.861957  1177.965147
# 586    48.753720  74.054292   1.461383   9.942616  -5.767915  1175.147580
# 587    50.292959  75.931692   1.327189   9.815137  -4.778449  1172.320567
#
#           y_pixel
# index
# 583    525.163670 ...
# 584    528.888866 ...
# 585    532.653384 ...
# 586    536.418472 ...
# 587    540.184449 ...
#
# [5 rows x 27 columns]

# %%
sb_nn = sb.pivot(index='depth_km', columns='along_strike_km', values='sig_nn')

# %%
plt.pcolormesh(sb_nn.values)

plt.show()

# %%
plt.scatter(sb.along_strike_km, sb.depth_km, c=sb.sig_nn)
plt.colorbar()

plt.gca().invert_xaxis()
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ### Need to figure out how/if to grid

# %% [markdown]
# ## Tong

# %%
t = pd.read_csv('../slip_models/tong/tong_topo_stress.csv', index_col=0)

# %%
t.iloc[0]
# Out:
# east_utm48     4.240790e+05
# north_utm48    3.474353e+06
# z              2.227975e+01
# strike_slip   -5.181966e-21
# dip_slip       8.576003e-01
# net_slip       8.576003e-01
# strike        -1.280000e+02
# dip            7.000000e+01
# xx_stress      2.799333e+01
# yy_stress      3.078429e+01
# zz_stress      2.636562e+01
# xy_stress     -8.981182e-01
# xz_stress      1.115747e+01
# yz_stress     -7.705105e+00
# x_pixel        1.262245e+03
# y_pixel        5.380005e+02
# z_pixel        2.142875e+01
# sig_nn         3.842104e+01
# tau_dd        -8.553114e+00
# tau_ss         3.164613e-01
# tau_cs        -1.449366e+01
# Name: 0, dtype: float64

# %%
t.dip.unique()
# Out:
# array([ 70.,  35.,  25.])

# %%
plt.scatter(zz.utm_lon, zz.utm_lat, s=3)

plt.scatter(t.east_utm48, t.north_utm48, c=t.z, lw=0)

plt.colorbar()

plt.show()

# %%
tt = pd.read_csv('../slip_models/tong/tong_lms.csv', index_col=0)

# %%
tt.head()
# Out:
#    east_utm48  north_utm48           z   strike_slip  dip_slip  net_slip  \
# 0      556466      3617519 -477.220248  5.181966e-21  0.857600  0.857600
# 1      538795      3610145 -477.220248 -1.984664e-20  2.270876  2.270876
# 2      521124      3602772 -477.220248 -1.771755e+00  6.622272  6.855188
# 3      503453      3595398 -477.220248 -5.365538e+00  4.824094  7.215322
# 4      485782      3588025 -477.220248 -5.977839e+00  1.853180  6.258502
#
#    strike  dip
# 0    -128   70
# 1    -128   70
# 2    -128   70
# 3    -128   70
# 4    -128   70
#
# [5 rows x 8 columns]

# %%
plt.scatter(zz.utm_lon, zz.utm_lat, s=3)

plt.scatter(tt.east_utm48, tt.north_utm48, c=tt.z, lw=0)

plt.colorbar()

plt.show()

# %% [markdown]
# ### Ok, still need to fix coordinates

# %% [markdown]
# ## Feng

# %%
fb = pd.read_csv('../slip_models/feng/feng_beich.csv', index_col=0)
fp = pd.read_csv('../slip_models/feng/feng_peng.csv', index_col=0)

# %%
fb.iloc[0]
# Out:
# azimuth         36.001
# bottom              -4
# depth                2
# dip                 67
# dip_m           1.2701
# e_trace       228.9709
# easting       228.2841
# fault_seg           s1
# lat           32.59335
# lat_c1        177.4075
# lat_c2        175.0563
# lon           105.4196
# lon_c1         230.589
# lon_c2        227.3529
# n_trace       176.2319
# northing      176.7309
# pt_index             0
# sig_nn        16.13494
# strike         216.001
# strike_m        0.6808
# tau_cs       -2.227998
# tau_dd        0.727678
# tau_ss       -7.417358
# top                 -0
# utm_lat        3606285
# utm_lon         539376
# x_pixel       1398.165
# xx_stress     11.59959
# xy_stress    0.6417662
# xz_stress    -1.037034
# y_pixel       693.5308
# yy_stress     30.21103
# yz_stress     2.483645
# z_pixel          0.149
# zz_stress      19.8364
# Name: 0, dtype: object

# %%
fb.strike.unique()
# Out:
# array([ 216.001 ,  226.7594,  225.7005])

# %%
fb['trace_dist_km'], fb['along_strike_km'] = hsp.rotate_pts_2d(fb.easting, 
                                                               fb.northing,
                                                               rot_p['x0'], rot_p['y0'],
                                                               rot_p['rot_angle']) * 0.001

fp['trace_dist_km'], fp['along_strike_km'] = hsp.rotate_pts_2d(fp.easting, 
                                                               fp.northing,
                                                               rot_p['x0'], rot_p['y0'],
                                                               rot_p['rot_angle']) * 0.001

# %%
f1 = fb[fb.strike == 216.001]
f2 = fb[fb.strike == 226.7594]
f3 = fb[fb.strike == 225.7005]

# %%
 fb.describe()
# Out:
#           azimuth      bottom       depth         dip       dip_m     e_trace  \
# count  584.000000  584.000000  584.000000  584.000000  584.000000  584.000000
# mean    44.497710  -18.000000   16.000000   57.684932    1.328559  125.284228
# std      3.802371    9.173008    9.173008    9.985068    1.409368   58.622006
# min     36.001000  -32.000000    2.000000   47.000000    0.000000   25.292300
# 25%     45.700500  -25.000000    9.000000   47.000000    0.205275   75.577700
# 50%     45.700500  -18.000000   16.000000   67.000000    0.847100  124.839000
# 75%     46.759400  -11.000000   23.000000   67.000000    1.987150  174.163550
# max     46.759400   -4.000000   30.000000   67.000000    6.693000  228.970950
#
#           easting         lat      lat_c1      lat_c2         lon      lon_c1  \
# count  584.000000  584.000000  584.000000  584.000000  584.000000  584.000000
# mean   117.806827   31.774656   79.675897   76.878286  104.245159  126.707534
# std     61.084607    0.514014   59.572412   59.682449    0.649365   58.670407
# min      5.753991   30.797812  -22.738500  -25.601300  103.053973   26.689100
# 25%     64.184663   31.336540   28.791800   25.929000  103.675125   76.974500
# 50%    120.186325   31.765158   79.417500   76.503600  104.270455  126.209100
# 75%    170.195937   32.227671  131.868300  128.954400  104.802086  175.533700
# max    228.284144   32.656206  177.407500  175.056300  105.419597  230.589000
#
#            lon_c2     n_trace    northing    pt_index      sig_nn      strike  \
# count  584.000000  584.000000  584.000000  584.000000  584.000000  584.000000
# mean   123.860922   78.277092   85.736749  291.500000   47.261854  224.497710
# std     58.573696   59.627373   57.130343  168.730554   16.683767    3.802371
# min     23.895500  -24.169900  -22.835100    0.000000   16.134942  216.001000
# 25%     74.180900   27.360400   37.042100  145.750000   33.180298  225.700500
# 50%    123.468900   77.960550   84.681076  291.500000   40.873029  225.700500
# 75%    172.793400  130.411350  136.087403  437.250000   63.763385  226.759400
# max    227.352900  176.231900  183.717081  583.000000   81.746763  226.759400
#
#          strike_m      tau_cs      tau_dd      tau_ss         top  \
# count  584.000000  584.000000  584.000000  584.000000  584.000000
# mean     1.342371  -18.779311   -7.980923   -1.853808  -14.000000
# std      1.089809    7.951591    4.885569    3.574976    9.173008
# min     -0.000000  -41.745181  -19.816776  -11.401998  -28.000000
# 25%      0.330150  -25.859572  -11.621520   -4.723491  -21.000000
# 50%      1.231850  -15.521216   -7.542506   -2.247452  -14.000000
# 75%      2.127250  -12.375303   -5.010792    1.390881   -7.000000
# max      4.286500   -2.227998    7.237433    6.784696   -0.000000
#
#               utm_lat        utm_lon      x_pixel   xx_stress   xy_stress  \
# count      584.000000     584.000000   584.000000  584.000000  584.000000
# mean   3515888.033944  428192.299442  1267.093900   31.821936    0.512036
# std      56556.634248   61876.307582    72.944059    9.543007    1.316505
# min    3408507.424617  314137.516901  1132.638257   11.560375   -9.605054
# 25%    3467522.266408  374104.861926  1203.331899   23.530492   -0.125934
# 50%    3514756.143289  430902.940589  1270.289391   30.611184    0.560196
# 75%    3565689.223086  481352.249936  1329.762516   39.693093    1.404827
# max    3613219.419379  539376.002495  1398.164917   50.581554    2.948732
#
#         xz_stress     y_pixel   yy_stress   yz_stress     z_pixel   zz_stress  \
# count  584.000000  584.000000  584.000000  584.000000  584.000000  584.000000
# mean     7.749886  586.964862   38.505680   -5.231256   14.149000   46.210331
# std      4.885801   66.672861    5.107156    3.664561    9.173008   15.104157
# min     -8.097296  460.377194   27.389496  -18.844972    0.149000   19.836398
# 25%      4.055770  529.947960   34.428369   -8.151876    7.149000   34.316730
# 50%      7.246648  585.630511   36.345846   -4.779451   14.149000   38.436173
# 75%     11.765256  645.673938   42.541649   -2.934385   21.149000   61.053251
# max     17.556008  701.705811   60.803953    9.349060   28.149000   82.930609
#
#        trace_dist_km  along_strike_km
# count     584.000000       584.000000
# mean     2181.536793     -2625.632540
# std         0.007292         0.083319
# min      2181.519526     -2625.775629
# 25%      2181.532564     -2625.703570
# 50%      2181.538184     -2625.632850
# 75%      2181.542507     -2625.560804
# max      2181.550279     -2625.490051
#
# [8 rows x 36 columns]

# %% [markdown]
# ## Fielding

# %%
flb = pd.read_csv('../slip_models/fielding/field_beich_topo_stress.csv', index_col=0)

